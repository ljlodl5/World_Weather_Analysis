# %%
# Import the random module.
import random
# Import the NumPy module.
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
import pandas as pd
# Import the datetime module from the datetime library.
from datetime import datetime
cities = []
city_data = []

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    country = citipy.nearest_city(coordinate[0], coordinate[1]).country_code
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 712

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_info = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_info})
                          #"Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ambon
# Processing Record 2 of Set 1 | kavieng
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | provideniya
# Processing Record 5 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 1 | san policarpo
# Processing Record 7 of Set 1 | teknaf
# Processing Record 8 of Set 1 | shakhtinsk
# Processing Record 9 of Set 1 | yining
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | placerville
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | fort-shevchenko
# Processing Record 15 of Set 1 | canar
# Processing Record 16 of Set 1 | mayo
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | havoysund
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | humaita
# Processing Record 22 of Set 1 | entre rios
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | jibuti
# Processing Record 25 of Set 1 | mahebourg
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | mae sot
# Processing Record 29 of Set 1 | kuala terengganu
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | den helder
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | manaure
# Processing Record 37 of Set 1 | cidreira
# Processing Record 38 of Set 1 | cascais
# Processing Record 39 of Set 1 | laguna
# Processing Record 40 of Set 1 | poso
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 1 | olinda
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | tsienyane
# City not found. Skipping...
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | strezhevoy
# Processing Record 48 of Set 1 | la ronge
# Processing Record 49 of Set 1 | safford
# Processing Record 50 of Set 1 | hamilton
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | samarai
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | tessalit
# Processing Record 5 of Set 2 | klaksvik
# Processing Record 6 of Set 2 | selikhino
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | udachnyy
# Processing Record 9 of Set 2 | chitipa
# Processing Record 10 of Set 2 | new port richey
# Processing Record 11 of Set 2 | aleksandrov gay
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | pangnirtung
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | batemans bay
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | marzuq
# Processing Record 21 of Set 2 | warrnambool
# Processing Record 22 of Set 2 | kozan
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | moose factory
# Processing Record 25 of Set 2 | kalangala
# Processing Record 26 of Set 2 | harper
# Processing Record 27 of Set 2 | sorland
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | kiruna
# Processing Record 30 of Set 2 | murud
# Processing Record 31 of Set 2 | najran
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | jalu
# Processing Record 34 of Set 2 | broome
# Processing Record 35 of Set 2 | aksarka
# Processing Record 36 of Set 2 | buala
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | makakilo city
# Processing Record 39 of Set 2 | gamba
# Processing Record 40 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 2 | alekseyevskaya
# Processing Record 42 of Set 2 | putnok
# Processing Record 43 of Set 2 | dikson
# Processing Record 44 of Set 2 | westport
# Processing Record 45 of Set 2 | neiafu
# Processing Record 46 of Set 2 | nikolskoye
# Processing Record 47 of Set 2 | wahpeton
# Processing Record 48 of Set 2 | margate
# Processing Record 49 of Set 2 | phan thiet
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | carmo do paranaiba
# Processing Record 2 of Set 3 | yerofey pavlovich
# Processing Record 3 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 3 | mehamn
# Processing Record 5 of Set 3 | vestmannaeyjar
# Processing Record 6 of Set 3 | esperance
# Processing Record 7 of Set 3 | mazatan
# Processing Record 8 of Set 3 | yeppoon
# Processing Record 9 of Set 3 | aklavik
# Processing Record 10 of Set 3 | chara
# Processing Record 11 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 3 | tuktoyaktuk
# Processing Record 13 of Set 3 | axim
# Processing Record 14 of Set 3 | port hardy
# Processing Record 15 of Set 3 | birigui
# Processing Record 16 of Set 3 | upernavik
# Processing Record 17 of Set 3 | port elizabeth
# Processing Record 18 of Set 3 | meulaboh
# Processing Record 19 of Set 3 | east london
# Processing Record 20 of Set 3 | beloha
# Processing Record 21 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 3 | taree
# Processing Record 23 of Set 3 | camacha
# Processing Record 24 of Set 3 | kodiak
# Processing Record 25 of Set 3 | oeiras do para
# Processing Record 26 of Set 3 | usinsk
# Processing Record 27 of Set 3 | susangerd
# Processing Record 28 of Set 3 | narsaq
# Processing Record 29 of Set 3 | palmer
# Processing Record 30 of Set 3 | punta arenas
# Processing Record 31 of Set 3 | vlahita
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | abha
# Processing Record 34 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 3 | kapoeta
# Processing Record 36 of Set 3 | saint george
# Processing Record 37 of Set 3 | bela
# Processing Record 38 of Set 3 | nalut
# Processing Record 39 of Set 3 | coquimbo
# Processing Record 40 of Set 3 | la rochelle
# Processing Record 41 of Set 3 | saint-philippe
# Processing Record 42 of Set 3 | pitimbu
# Processing Record 43 of Set 3 | severo-kurilsk
# Processing Record 44 of Set 3 | vavuniya
# Processing Record 45 of Set 3 | saskylakh
# Processing Record 46 of Set 3 | sarakhs
# Processing Record 47 of Set 3 | norman wells
# Processing Record 48 of Set 3 | clyde river
# Processing Record 49 of Set 3 | lebu
# Processing Record 50 of Set 3 | sharanga
# Processing Record 1 of Set 4 | billings
# Processing Record 2 of Set 4 | heihe
# Processing Record 3 of Set 4 | cabo san lucas
# Processing Record 4 of Set 4 | torbay
# Processing Record 5 of Set 4 | waipawa
# Processing Record 6 of Set 4 | ginda
# Processing Record 7 of Set 4 | mabopane
# Processing Record 8 of Set 4 | kuminskiy
# Processing Record 9 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 4 | martapura
# Processing Record 11 of Set 4 | iranshahr
# Processing Record 12 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 4 | tura
# Processing Record 14 of Set 4 | mogok
# Processing Record 15 of Set 4 | outjo
# Processing Record 16 of Set 4 | tasiilaq
# Processing Record 17 of Set 4 | severnyy
# Processing Record 18 of Set 4 | butaritari
# Processing Record 19 of Set 4 | seoul
# Processing Record 20 of Set 4 | castro
# Processing Record 21 of Set 4 | gurgan
# City not found. Skipping...
# Processing Record 22 of Set 4 | san quintin
# Processing Record 23 of Set 4 | ho chi minh city
# Processing Record 24 of Set 4 | puerto ayora
# Processing Record 25 of Set 4 | la quinta
# Processing Record 26 of Set 4 | capreol
# Processing Record 27 of Set 4 | ponta do sol
# Processing Record 28 of Set 4 | huarmey
# Processing Record 29 of Set 4 | pesqueira
# Processing Record 30 of Set 4 | boa vista
# Processing Record 31 of Set 4 | sorkjosen
# Processing Record 32 of Set 4 | tigil
# Processing Record 33 of Set 4 | olafsvik
# Processing Record 34 of Set 4 | qaanaaq
# Processing Record 35 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 4 | mount isa
# Processing Record 37 of Set 4 | mamontovo
# Processing Record 38 of Set 4 | port-gentil
# Processing Record 39 of Set 4 | mocuba
# Processing Record 40 of Set 4 | bengkulu
# Processing Record 41 of Set 4 | daru
# Processing Record 42 of Set 4 | boguchany
# Processing Record 43 of Set 4 | mizur
# Processing Record 44 of Set 4 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 45 of Set 4 | ingham
# Processing Record 46 of Set 4 | aranos
# Processing Record 47 of Set 4 | russell
# Processing Record 48 of Set 4 | namibe
# Processing Record 49 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 4 | pacific grove
# Processing Record 1 of Set 5 | kavaratti
# Processing Record 2 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 5 | inuvik
# Processing Record 4 of Set 5 | lata
# Processing Record 5 of Set 5 | leningradskiy
# Processing Record 6 of Set 5 | inirida
# Processing Record 7 of Set 5 | cabedelo
# Processing Record 8 of Set 5 | mayahi
# Processing Record 9 of Set 5 | nome
# Processing Record 10 of Set 5 | srednekolymsk
# Processing Record 11 of Set 5 | batagay-alyta
# Processing Record 12 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 5 | tocopilla
# Processing Record 14 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 5 | maragogi
# Processing Record 16 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 17 of Set 5 | catuday
# Processing Record 18 of Set 5 | zhigansk
# Processing Record 19 of Set 5 | wiwili
# Processing Record 20 of Set 5 | leo
# Processing Record 21 of Set 5 | kaitangata
# Processing Record 22 of Set 5 | edd
# Processing Record 23 of Set 5 | luklukan
# Processing Record 24 of Set 5 | rawson
# Processing Record 25 of Set 5 | launceston
# Processing Record 26 of Set 5 | pilar
# Processing Record 27 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 5 | lorengau
# Processing Record 29 of Set 5 | chuy
# Processing Record 30 of Set 5 | longyearbyen
# Processing Record 31 of Set 5 | lauchhammer
# Processing Record 32 of Set 5 | okhotsk
# Processing Record 33 of Set 5 | varhaug
# Processing Record 34 of Set 5 | derzhavinsk
# Processing Record 35 of Set 5 | grindavik
# Processing Record 36 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 5 | osorno
# Processing Record 38 of Set 5 | thespiai
# City not found. Skipping...
# Processing Record 39 of Set 5 | taltal
# Processing Record 40 of Set 5 | doha
# Processing Record 41 of Set 5 | amga
# Processing Record 42 of Set 5 | carnarvon
# Processing Record 43 of Set 5 | okha
# Processing Record 44 of Set 5 | porto novo
# Processing Record 45 of Set 5 | hambantota
# Processing Record 46 of Set 5 | yar-sale
# Processing Record 47 of Set 5 | praia
# Processing Record 48 of Set 5 | lagunas
# Processing Record 49 of Set 5 | zepce
# Processing Record 50 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 1 of Set 6 | chumikan
# Processing Record 2 of Set 6 | raton
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | antofagasta
# Processing Record 5 of Set 6 | nandi
# Processing Record 6 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 7 of Set 6 | yemelyanovo
# Processing Record 8 of Set 6 | vasteras
# Processing Record 9 of Set 6 | alta floresta
# Processing Record 10 of Set 6 | cherskiy
# Processing Record 11 of Set 6 | kununurra
# Processing Record 12 of Set 6 | mirnyy
# Processing Record 13 of Set 6 | brigantine
# Processing Record 14 of Set 6 | saint-joseph
# Processing Record 15 of Set 6 | araioses
# Processing Record 16 of Set 6 | totma
# Processing Record 17 of Set 6 | port macquarie
# Processing Record 18 of Set 6 | virpur
# Processing Record 19 of Set 6 | warman
# Processing Record 20 of Set 6 | nelson bay
# Processing Record 21 of Set 6 | hirara
# Processing Record 22 of Set 6 | ostrovnoy
# Processing Record 23 of Set 6 | saint-maximin-la-sainte-baume
# Processing Record 24 of Set 6 | kemijarvi
# Processing Record 25 of Set 6 | shaunavon
# Processing Record 26 of Set 6 | komsomolskiy
# Processing Record 27 of Set 6 | faanui
# Processing Record 28 of Set 6 | luderitz
# Processing Record 29 of Set 6 | sao filipe
# Processing Record 30 of Set 6 | henties bay
# Processing Record 31 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 6 | bubaque
# Processing Record 33 of Set 6 | mouzakion
# City not found. Skipping...
# Processing Record 34 of Set 6 | port lincoln
# Processing Record 35 of Set 6 | boyolangu
# Processing Record 36 of Set 6 | comodoro rivadavia
# Processing Record 37 of Set 6 | ishim
# Processing Record 38 of Set 6 | komatipoort
# Processing Record 39 of Set 6 | geraldton
# Processing Record 40 of Set 6 | abu kamal
# Processing Record 41 of Set 6 | omsukchan
# Processing Record 42 of Set 6 | chirongui
# Processing Record 43 of Set 6 | rio grande
# Processing Record 44 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 45 of Set 6 | haines junction
# Processing Record 46 of Set 6 | kedrovyy
# Processing Record 47 of Set 6 | matamoros
# Processing Record 48 of Set 6 | long xuyen
# Processing Record 49 of Set 6 | kinkala
# Processing Record 50 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 2 of Set 7 | nang rong
# Processing Record 3 of Set 7 | saint-augustin
# Processing Record 4 of Set 7 | kropotkin
# Processing Record 5 of Set 7 | maniitsoq
# Processing Record 6 of Set 7 | bambous virieux
# Processing Record 7 of Set 7 | anchorage
# Processing Record 8 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 9 of Set 7 | riohacha
# Processing Record 10 of Set 7 | oranjemund
# Processing Record 11 of Set 7 | abyek
# Processing Record 12 of Set 7 | constitucion
# Processing Record 13 of Set 7 | katobu
# Processing Record 14 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 7 | odienne
# Processing Record 16 of Set 7 | aripuana
# Processing Record 17 of Set 7 | ussel
# Processing Record 18 of Set 7 | mudgee
# Processing Record 19 of Set 7 | hasaki
# Processing Record 20 of Set 7 | lompoc
# Processing Record 21 of Set 7 | kanaya
# Processing Record 22 of Set 7 | alofi
# Processing Record 23 of Set 7 | shambu
# Processing Record 24 of Set 7 | bratsk
# Processing Record 25 of Set 7 | taoudenni
# Processing Record 26 of Set 7 | roma
# Processing Record 27 of Set 7 | biltine
# Processing Record 28 of Set 7 | touros
# Processing Record 29 of Set 7 | korla
# Processing Record 30 of Set 7 | arrecife
# Processing Record 31 of Set 7 | ilulissat
# Processing Record 32 of Set 7 | deputatskiy
# Processing Record 33 of Set 7 | warwick
# Processing Record 34 of Set 7 | sangar
# Processing Record 35 of Set 7 | amazar
# Processing Record 36 of Set 7 | caravelas
# Processing Record 37 of Set 7 | arambagh
# Processing Record 38 of Set 7 | amboasary
# Processing Record 39 of Set 7 | podosinovets
# Processing Record 40 of Set 7 | agadez
# Processing Record 41 of Set 7 | thompson
# Processing Record 42 of Set 7 | chebenki
# Processing Record 43 of Set 7 | namatanai
# Processing Record 44 of Set 7 | ayan
# Processing Record 45 of Set 7 | bonavista
# Processing Record 46 of Set 7 | sakakah
# Processing Record 47 of Set 7 | new ross
# Processing Record 48 of Set 7 | fort saint james
# Processing Record 49 of Set 7 | ahipara
# Processing Record 50 of Set 7 | boueni
# Processing Record 1 of Set 8 | wakkanai
# Processing Record 2 of Set 8 | opuwo
# Processing Record 3 of Set 8 | bereda
# Processing Record 4 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 5 of Set 8 | brae
# Processing Record 6 of Set 8 | portland
# Processing Record 7 of Set 8 | sai buri
# Processing Record 8 of Set 8 | vilhena
# Processing Record 9 of Set 8 | kushmurun
# Processing Record 10 of Set 8 | koslan
# Processing Record 11 of Set 8 | prokopyevsk
# Processing Record 12 of Set 8 | bang saphan
# Processing Record 13 of Set 8 | khandyga
# Processing Record 14 of Set 8 | ternate
# Processing Record 15 of Set 8 | ancona
# Processing Record 16 of Set 8 | vanimo
# Processing Record 17 of Set 8 | nichinan
# Processing Record 18 of Set 8 | atar
# Processing Record 19 of Set 8 | acapulco
# Processing Record 20 of Set 8 | pueblo
# Processing Record 21 of Set 8 | fort frances
# Processing Record 22 of Set 8 | wattegama
# Processing Record 23 of Set 8 | wangkui
# Processing Record 24 of Set 8 | kokstad
# Processing Record 25 of Set 8 | port blair
# Processing Record 26 of Set 8 | helensburgh
# Processing Record 27 of Set 8 | thinadhoo
# Processing Record 28 of Set 8 | jiblah
# Processing Record 29 of Set 8 | sadri
# Processing Record 30 of Set 8 | solnechnyy
# Processing Record 31 of Set 8 | bonthe
# Processing Record 32 of Set 8 | nanortalik
# Processing Record 33 of Set 8 | te anau
# Processing Record 34 of Set 8 | esmeraldas
# Processing Record 35 of Set 8 | ciudad bolivar
# Processing Record 36 of Set 8 | tromso
# Processing Record 37 of Set 8 | chiredzi
# Processing Record 38 of Set 8 | sola
# Processing Record 39 of Set 8 | iqaluit
# Processing Record 40 of Set 8 | guerrero negro
# Processing Record 41 of Set 8 | juneau
# Processing Record 42 of Set 8 | ossora
# Processing Record 43 of Set 8 | yumen
# Processing Record 44 of Set 8 | paamiut
# Processing Record 45 of Set 8 | tucuman
# Processing Record 46 of Set 8 | biak
# Processing Record 47 of Set 8 | saint-francois
# Processing Record 48 of Set 8 | sept-iles
# Processing Record 49 of Set 8 | luan
# Processing Record 50 of Set 8 | lisakovsk
# Processing Record 1 of Set 9 | cam ranh
# Processing Record 2 of Set 9 | yamada
# Processing Record 3 of Set 9 | darhan
# Processing Record 4 of Set 9 | palembang
# Processing Record 5 of Set 9 | longford
# Processing Record 6 of Set 9 | puerto penasco
# Processing Record 7 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 8 of Set 9 | sioux lookout
# Processing Record 9 of Set 9 | molln
# Processing Record 10 of Set 9 | sarh
# Processing Record 11 of Set 9 | terney
# Processing Record 12 of Set 9 | beringovskiy
# Processing Record 13 of Set 9 | rancho palos verdes
# Processing Record 14 of Set 9 | west wendover
# Processing Record 15 of Set 9 | morondava
# Processing Record 16 of Set 9 | erzin
# Processing Record 17 of Set 9 | batagay
# Processing Record 18 of Set 9 | sena madureira
# Processing Record 19 of Set 9 | san isidro
# Processing Record 20 of Set 9 | marfino
# Processing Record 21 of Set 9 | colquiri
# Processing Record 22 of Set 9 | hay river
# Processing Record 23 of Set 9 | isangel
# Processing Record 24 of Set 9 | wufeng
# Processing Record 25 of Set 9 | labuhan
# Processing Record 26 of Set 9 | bandarbeyla
# Processing Record 27 of Set 9 | roald
# Processing Record 28 of Set 9 | flin flon
# Processing Record 29 of Set 9 | tucurui
# Processing Record 30 of Set 9 | valparaiso
# Processing Record 31 of Set 9 | puerto madero
# Processing Record 32 of Set 9 | guymon
# Processing Record 33 of Set 9 | assiniboia
# Processing Record 34 of Set 9 | tanout
# Processing Record 35 of Set 9 | colinas
# Processing Record 36 of Set 9 | yantal
# Processing Record 37 of Set 9 | kramat
# Processing Record 38 of Set 9 | senj
# Processing Record 39 of Set 9 | naze
# Processing Record 40 of Set 9 | tezu
# Processing Record 41 of Set 9 | yerbogachen
# Processing Record 42 of Set 9 | staraya mayna
# Processing Record 43 of Set 9 | ambatondrazaka
# Processing Record 44 of Set 9 | saldanha
# Processing Record 45 of Set 9 | murray bridge
# Processing Record 46 of Set 9 | yulara
# Processing Record 47 of Set 9 | juchitlan
# Processing Record 48 of Set 9 | dwarka
# Processing Record 49 of Set 9 | kalmunai
# Processing Record 50 of Set 9 | sohbatpur
# Processing Record 1 of Set 10 | vila franca do campo
# Processing Record 2 of Set 10 | koumac
# Processing Record 3 of Set 10 | rio de jesus
# Processing Record 4 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 5 of Set 10 | port hedland
# Processing Record 6 of Set 10 | along
# Processing Record 7 of Set 10 | mikhaylovka
# Processing Record 8 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 10 | nabire
# Processing Record 10 of Set 10 | kieta
# Processing Record 11 of Set 10 | lucea
# Processing Record 12 of Set 10 | raudeberg
# Processing Record 13 of Set 10 | codrington
# Processing Record 14 of Set 10 | mancio lima
# Processing Record 15 of Set 10 | sitio novo do tocantins
# Processing Record 16 of Set 10 | sibolga
# Processing Record 17 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 10 | aya
# Processing Record 19 of Set 10 | emerald
# Processing Record 20 of Set 10 | bestobe
# Processing Record 21 of Set 10 | dandong
# Processing Record 22 of Set 10 | thiruvananthapuram
# Processing Record 23 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 10 | markova
# Processing Record 25 of Set 10 | san cristobal
# Processing Record 26 of Set 10 | poronaysk
# Processing Record 27 of Set 10 | swellendam
# Processing Record 28 of Set 10 | general roca
# Processing Record 29 of Set 10 | padang
# Processing Record 30 of Set 10 | adrar
# Processing Record 31 of Set 10 | peleduy
# Processing Record 32 of Set 10 | dryden
# Processing Record 33 of Set 10 | cooma
# Processing Record 34 of Set 10 | mugango
# Processing Record 35 of Set 10 | marsa matruh
# Processing Record 36 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 10 | gaogou
# Processing Record 38 of Set 10 | grand gaube
# Processing Record 39 of Set 10 | souillac
# Processing Record 40 of Set 10 | litovko
# Processing Record 41 of Set 10 | vardo
# Processing Record 42 of Set 10 | asilah
# Processing Record 43 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 44 of Set 10 | boende
# Processing Record 45 of Set 10 | gisborne
# Processing Record 46 of Set 10 | fortuna
# Processing Record 47 of Set 10 | szczytno
# Processing Record 48 of Set 10 | leh
# Processing Record 49 of Set 10 | pechora
# Processing Record 50 of Set 10 | dormidontovka
# Processing Record 1 of Set 11 | berlevag
# Processing Record 2 of Set 11 | matara
# Processing Record 3 of Set 11 | carauari
# Processing Record 4 of Set 11 | sakaiminato
# Processing Record 5 of Set 11 | sosua
# Processing Record 6 of Set 11 | hualmay
# Processing Record 7 of Set 11 | anadyr
# Processing Record 8 of Set 11 | malpe
# Processing Record 9 of Set 11 | krasnoselkup
# Processing Record 10 of Set 11 | endicott
# Processing Record 11 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 11 | itarema
# Processing Record 13 of Set 11 | tobermory
# Processing Record 14 of Set 11 | bereznik
# Processing Record 15 of Set 11 | ancud
# Processing Record 16 of Set 11 | atambua
# Processing Record 17 of Set 11 | coihaique
# Processing Record 18 of Set 11 | bouna
# Processing Record 19 of Set 11 | avera
# Processing Record 20 of Set 11 | morogoro
# Processing Record 21 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 22 of Set 11 | marrakesh
# Processing Record 23 of Set 11 | the valley
# Processing Record 24 of Set 11 | rehoboth
# Processing Record 25 of Set 11 | saint anthony
# Processing Record 26 of Set 11 | muskegon
# Processing Record 27 of Set 11 | pevek
# Processing Record 28 of Set 11 | santiago
# Processing Record 29 of Set 11 | iramuco
# Processing Record 30 of Set 11 | puerto carreno
# Processing Record 31 of Set 11 | kenai
# Processing Record 32 of Set 11 | loyga
# Processing Record 33 of Set 11 | hami
# Processing Record 34 of Set 11 | tautira
# Processing Record 35 of Set 11 | camacupa
# Processing Record 36 of Set 11 | lavrentiya
# Processing Record 37 of Set 11 | lagoa
# Processing Record 38 of Set 11 | belyy yar
# Processing Record 39 of Set 11 | atasu
# Processing Record 40 of Set 11 | nantucket
# Processing Record 41 of Set 11 | cap malheureux
# Processing Record 42 of Set 11 | creel
# Processing Record 43 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 11 | bathsheba
# Processing Record 45 of Set 11 | nyurba
# Processing Record 46 of Set 11 | kobe
# Processing Record 47 of Set 11 | la asuncion
# Processing Record 48 of Set 11 | suzdal
# Processing Record 49 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 11 | jiaocheng
# Processing Record 1 of Set 12 | tanete
# Processing Record 2 of Set 12 | karratha
# Processing Record 3 of Set 12 | guanare
# Processing Record 4 of Set 12 | puerto quijarro
# Processing Record 5 of Set 12 | vitry-le-francois
# Processing Record 6 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 12 | andenes
# Processing Record 8 of Set 12 | evensk
# Processing Record 9 of Set 12 | nouadhibou
# Processing Record 10 of Set 12 | koundara
# Processing Record 11 of Set 12 | progreso
# Processing Record 12 of Set 12 | naifaru
# Processing Record 13 of Set 12 | auki
# Processing Record 14 of Set 12 | mackay
# Processing Record 15 of Set 12 | ushtobe
# Processing Record 16 of Set 12 | beidao
# Processing Record 17 of Set 12 | agogo
# Processing Record 18 of Set 12 | sinop
# Processing Record 19 of Set 12 | long beach
# Processing Record 20 of Set 12 | kruisfontein
# Processing Record 21 of Set 12 | karaton
# Processing Record 22 of Set 12 | cape coast
# Processing Record 23 of Set 12 | gat
# Processing Record 24 of Set 12 | morros
# Processing Record 25 of Set 12 | ampanihy
# Processing Record 26 of Set 12 | kuah
# Processing Record 27 of Set 12 | college
# Processing Record 28 of Set 12 | rolla
# Processing Record 29 of Set 12 | romodanovo
# Processing Record 30 of Set 12 | ilanskiy
# Processing Record 31 of Set 12 | tuatapere
# Processing Record 32 of Set 12 | burnie
# Processing Record 33 of Set 12 | kitimat
# Processing Record 34 of Set 12 | yilan
# Processing Record 35 of Set 12 | tequila
# Processing Record 36 of Set 12 | semiletka
# Processing Record 37 of Set 12 | harbour breton
# Processing Record 38 of Set 12 | pacasmayo
# Processing Record 39 of Set 12 | talagang
# Processing Record 40 of Set 12 | caceres
# Processing Record 41 of Set 12 | akyab
# Processing Record 42 of Set 12 | hit
# Processing Record 43 of Set 12 | rocha
# Processing Record 44 of Set 12 | northam
# Processing Record 45 of Set 12 | pantai remis
# Processing Record 46 of Set 12 | druzhba
# Processing Record 47 of Set 12 | husavik
# Processing Record 48 of Set 12 | tecpan
# Processing Record 49 of Set 12 | umaria
# Processing Record 50 of Set 12 | bina-etawa
# City not found. Skipping...
# Processing Record 1 of Set 13 | sisimiut
# Processing Record 2 of Set 13 | katsuura
# Processing Record 3 of Set 13 | hovd
# Processing Record 4 of Set 13 | port moresby
# Processing Record 5 of Set 13 | amot
# Processing Record 6 of Set 13 | sawakin
# Processing Record 7 of Set 13 | timiryazevskiy
# Processing Record 8 of Set 13 | port augusta
# Processing Record 9 of Set 13 | dondo
# Processing Record 10 of Set 13 | ustye
# Processing Record 11 of Set 13 | uruacu
# Processing Record 12 of Set 13 | herzberg
# Processing Record 13 of Set 13 | micheweni
# Processing Record 14 of Set 13 | ca mau
# Processing Record 15 of Set 13 | ostersund
# Processing Record 16 of Set 13 | banda aceh
# Processing Record 17 of Set 13 | kahului
# Processing Record 18 of Set 13 | oksfjord
# Processing Record 19 of Set 13 | balikpapan
# Processing Record 20 of Set 13 | tateyama
# Processing Record 21 of Set 13 | alekseyevsk
# Processing Record 22 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 13 | aldan
# Processing Record 24 of Set 13 | lasem
# Processing Record 25 of Set 13 | luanda
# Processing Record 26 of Set 13 | pran buri
# Processing Record 27 of Set 13 | tabukiniberu
# City not found. Skipping...
# Processing Record 28 of Set 13 | visnes
# Processing Record 29 of Set 13 | asnaes
# Processing Record 30 of Set 13 | alikalia
# Processing Record 31 of Set 13 | muhos
# Processing Record 32 of Set 13 | adamovka
# Processing Record 33 of Set 13 | san luis
# Processing Record 34 of Set 13 | lang suan
# Processing Record 35 of Set 13 | troitskoye
# Processing Record 36 of Set 13 | shipitsyno
# Processing Record 37 of Set 13 | payo
# Processing Record 38 of Set 13 | mayumba
# Processing Record 39 of Set 13 | rosetta
# Processing Record 40 of Set 13 | marystown
# Processing Record 41 of Set 13 | mikkeli
# Processing Record 42 of Set 13 | lakatoro
# Processing Record 43 of Set 13 | maarianhamina
# Processing Record 44 of Set 13 | lugazi
# Processing Record 45 of Set 13 | barabai
# Processing Record 46 of Set 13 | tartagal
# Processing Record 47 of Set 13 | kidal
# Processing Record 48 of Set 13 | chapais
# Processing Record 49 of Set 13 | walvis bay
# Processing Record 50 of Set 13 | nishihara
# Processing Record 1 of Set 14 | campo de criptana
# Processing Record 2 of Set 14 | urucara
# Processing Record 3 of Set 14 | aksu
# Processing Record 4 of Set 14 | etchoropo
# Processing Record 5 of Set 14 | taua
# Processing Record 6 of Set 14 | sitka
# Processing Record 7 of Set 14 | angoram
# Processing Record 8 of Set 14 | talnakh
# Processing Record 9 of Set 14 | ambulu
# Processing Record 10 of Set 14 | sur
# Processing Record 11 of Set 14 | sergeyevka
# Processing Record 12 of Set 14 | tilichiki
# Processing Record 13 of Set 14 | maroantsetra
# Processing Record 14 of Set 14 | sumter
# Processing Record 15 of Set 14 | nizhniy kuranakh
# Processing Record 16 of Set 14 | hailey
# Processing Record 17 of Set 14 | wanaka
# Processing Record 18 of Set 14 | lulea
# Processing Record 19 of Set 14 | yatou
# Processing Record 20 of Set 14 | muyezerskiy
# Processing Record 21 of Set 14 | waupun
# Processing Record 22 of Set 14 | ouango
# Processing Record 23 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 24 of Set 14 | moree
# Processing Record 25 of Set 14 | riyadh
# Processing Record 26 of Set 14 | tansen
# Processing Record 27 of Set 14 | inhambane
# Processing Record 28 of Set 14 | burgeo
# Processing Record 29 of Set 14 | ucluelet
# Processing Record 30 of Set 14 | cuite
# Processing Record 31 of Set 14 | aitape
# Processing Record 32 of Set 14 | nsoko
# Processing Record 33 of Set 14 | kulunda
# Processing Record 34 of Set 14 | port keats
# Processing Record 35 of Set 14 | ambilobe
# Processing Record 36 of Set 14 | carahue
# Processing Record 37 of Set 14 | les cayes
# Processing Record 38 of Set 14 | xingtai
# Processing Record 39 of Set 14 | dakar
# Processing Record 40 of Set 14 | tual
# Processing Record 41 of Set 14 | tabuk
# Processing Record 42 of Set 14 | dongsheng
# Processing Record 43 of Set 14 | taybad
# Processing Record 44 of Set 14 | diego de almagro
# Processing Record 45 of Set 14 | cap-chat
# Processing Record 46 of Set 14 | saint-georges
# Processing Record 47 of Set 14 | oudtshoorn
# Processing Record 48 of Set 14 | banes
# Processing Record 49 of Set 14 | finote selam
# Processing Record 50 of Set 14 | dingle
# Processing Record 1 of Set 15 | sao joao da barra
# Processing Record 2 of Set 15 | hobyo
# Processing Record 3 of Set 15 | shingu
# Processing Record 4 of Set 15 | iranduba
# Processing Record 5 of Set 15 | adre
# Processing Record 6 of Set 15 | kamenka
# Processing Record 7 of Set 15 | seymchan
# Processing Record 8 of Set 15 | fort nelson
# Processing Record 9 of Set 15 | tvoroyri
# Processing Record 10 of Set 15 | ust-ilimsk
# Processing Record 11 of Set 15 | sao jose da coroa grande
# Processing Record 12 of Set 15 | pisco
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ambon      ID  -3.6954  128.1814     86.14        89          20
# 1        Kavieng      PG  -2.5744  150.7967     84.90        69          86
# 2    Provideniya      RU  64.3833 -173.3000     28.51        54          75
# 3  San Policarpo      PH  12.1791  125.5072     83.80        78          47
# 4         Teknaf      BD  20.8624   92.3058     76.64        95         100
# 5     Shakhtinsk      KZ  49.7100   72.5872     36.84        50           5
# 6         Yining      CN  29.0361  114.5636     50.86        88          91
# 7      Hithadhoo      MV  -0.6000   73.0833     81.77        77         100
# 8          Vaini      TO -21.2000 -175.2000     82.56        83          40
# 9    Placerville      US  38.7296 -120.7986     64.63        50          75
#
#    Wind Speed Current Description
# 0        3.44          few clouds
# 1       12.48     overcast clouds
# 2       11.18       broken clouds
# 3        8.10    scattered clouds
# 4       12.80     overcast clouds
# 5        3.87           clear sky
# 6        1.48     overcast clouds
# 7       12.77     overcast clouds
# 8       10.36    scattered clouds
# 9        1.99       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
